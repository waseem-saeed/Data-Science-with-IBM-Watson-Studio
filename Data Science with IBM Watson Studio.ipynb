# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Waseem Saeed**
#
# Data Scientist

# %% [markdown]
# *I am interested in data science because of its potential to derive insights from large datasets and influence decision-making processes across various domains.*

# %% [markdown]
# ### Code Description
#
# The code in the next cell will execute a simple arithmetic operation: addition of two numbers, 1 and 1.

# %%
1 + 1
# Out:
# 2

# %% [markdown]
# Here's a demonstration of various Markdown features:
#
# - Bulleted list item 1
# - Bulleted list item 2
#
# 1. Numbered list item 1
# 2. Numbered list item 2
#
# | Column 1 | Column 2 |
# | -------- | -------- |
# | Row 1    | Data     |
# | Row 2    | Data     |
#
# [My LinkedIn Profile](https://www.linkedin.com/in/waseem-s/)
#
# ![IBM Logo](https://www.ibm.com/brand/experience-guides/developer/8f4e3cc2b5d52354a6d43c8edba1e3c9/02_8-bar-reverse.svg)
